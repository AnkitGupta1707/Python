# %% [markdown]
# # Lecture-4
# ## Python list and boolean variable

# %% [markdown]
# ### boolean variable

# %%
bool()
# Out:
# False

# %%
print(True,False)
# Out:
# True False

# %%
type(False)
# Out:
# bool

# %% [markdown]
# ### boolean and logical operation

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
True and True
# Out:
# True

# %%
str1="Helloworld"
str2="Ankit"

# %%
str1.isalpha() or str2.isnumeric()
# Out:
# True

# %% [markdown]
# ### list

# %%
type([])
# Out:
# list

# %%
# list=[]

# %%
# type(list)

# %%
del list

# %%
x=list()

# %%
type(x)
# Out:
# list

# %%
len(x)
# Out:
# 0

# %% [markdown]
# #### Append

# %%
x.append(1)

# %%
x
# Out:
# [1]

# %%
# append add element in the last of the list.

# %%
x.append(["hello",5])

# %%
x
# Out:
# [1, ['hello', 5]]

# %% [markdown]
# #### insert

# %%
x.insert(1,"world")

# %%
x
# Out:
# [1, 'world', ['hello', 5]]

# %% [markdown]
# #### extend

# %%
x.extend([5,"ankit"])

# %%
x
# Out:
# [1, 'world', ['hello', 5], 5, 'ankit']

# %% [markdown]
# #### Various Operations that we can perform in List

# %%
lst=[1,2,3,4,5]

# %%
sum(lst)
# Out:
# 15

# %% [markdown]
# #### POP Method

# %%
lst.pop()
# Out:
# 5

# %%
lst
# Out:
# [1, 2, 3, 4]

# %%
lst.pop(1)
# Out:
# 2

# %%
lst
# Out:
# [1, 3, 4]

# %% [markdown]
# #### Count():Calculate the total occurance of the element

# %%
lst.count(1)
# Out:
# 1

# %%
lst.count(2)
# Out:
# 0

# %%
# index will tell us about the index of first occurance
lst.index(1)
# Out:
# 0

# %%
min(lst)
# Out:
# 1

# %%
max(lst)
# Out:
# 4

# %%
lst*2
# Out:
# [1, 3, 4, 1, 3, 4]
