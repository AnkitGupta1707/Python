# %% [markdown]
# # lecture-3
# ## Python Tutorial

# %% [markdown]
# ### Datatype

# %%
1+1
# Out:
# 2

# %%
1-2
# Out:
# -1

# %%
2*3
# Out:
# 6

# %%
2/3
# Out:
# 0.6666666666666666

# %%
2//3
# Out:
# 0

# %%
2**3
# Out:
# 8

# %%
3%2
# Out:
# 1

# %%
10*'str'
# Out:
# 'strstrstrstrstrstrstrstrstrstr'

# %%
# check the data type

# %%
type(1.0)
# Out:
# float

# %%
type('str')
# Out:
# str

# %%
type('hello')
# Out:
# str

# %%
type(True)
# Out:
# bool

# %% [markdown]
# ## Strings

# %%
"hello"
# Out:
# 'hello'

# %%
type("hello")
# Out:
# str

# %% [markdown]
# ## Variable Assignment

# %%
# Syntax
# var_name=values
a=10

# %%
type(a)
# Out:
# int

# %%
# Nathematical operations with variable assignment
a=10
b=20

# %%
print(a*b)
print(a-b)
print(a+b)
print(a/b)
# Out:
# 200
# -10
# 30
# 0.5

# %%
# Various ways of Printing
print("ankit")
# Out:
# ankit

# %%
first_name="ankit"
last_name="gupta"

# %%
# place matters
print("My first name is {} and last name is {}".format(first_name,last_name))
# Out:
# My first name is ankit and last name is gupta

# %%
# place not matters
print("My first name is {first} and last name is {last}".format(first=first_name,last=last_name))
# Out:
# My first name is ankit and last name is gupta

# %%
print(f"my first name is {first_name} and last name is {last_name}")
# Out:
# my first name is ankit and last name is gupta

# %%
len('ankit')
# Out:
# 5
